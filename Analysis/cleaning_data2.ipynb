# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r'C:\Users\Anastasia\Documents\GitHub\ophthalmic_drugs\Data\merged_reviews1.csv')
df1
# Out:
#                                                SMILES           Name  \
# 0                        CC(=O)NC1=NN=C(S1)S(=O)(=O)N  acetazolamide
# 1                        CC(C)NCC(COC1=CC=CC=C1CC=C)O     alprenolol
# 2                   CC(C)NCC(COC1=CC=C(C=C1)CC(=O)N)O       atenolol
# 3        C1=CC=C(C=C1)S(=O)(=O)NC2=NN=C(S2)S(=O)(=O)N    benzolamide
# 4         CC1=CC(=CC=C1)OCC(CNCCC2=CC(=C(C=C2)OC)OC)O     bevantolol
# ..                                                ...            ...
# 65   CC12CC(C3C(C1CCC2(C(=O)CO)O)CCC4=CC(=O)C=CC34C)O   Prednisolone
# 66         COC1=CC2=C(C=CN=C2C=C1)C(C3CC4CCN3CC4C=C)O      Quinidine
# 67                   C1CN=C(N1)NC2=C(C=CC3=NSN=C32)Cl     Tizanidine
# 68  CC(C1=NC=NC=C1F)C(CN2C=NC=N2)(C3=C(C=C(C=C3)F)F)O   Voriconazole
# 69        CCCC(=O)NC1=CC(=C(C=C1)OCC(CNC(C)C)O)C(=O)C     Acebutolol
#
#     perm(cm/s)   loss                         DOI
# 0      9.10000   0.00         10.1021/jm00158a028
# ...

# %%
df2 = pd.read_csv(r'C:\Users\Anastasia\Documents\GitHub\ophthalmic_drugs\Data\Xuchun2002.csv')
df2['perm(cm/s)'] = df2['lopP'].apply(lambda s: s.replace ('?', '-'))
df2['perm(cm/s)'] = df2['perm(cm/s)'].astype(float)
df2['perm(cm/s)'] = df2['perm(cm/s)'].apply(lambda s: 10**s*10000000)
df2.insert(5, "loss", 0)
df2=df2[['SMILES', 'Name', 'perm(cm/s)', 'loss', 'DOI']]
df2
# Out:
#                                                SMILES  \
# 0     CC12CCC(=O)C=C1CCC3C2C(CC4(C3CCC4(C(=O)CO)O)C)O
# 1            CC(=O)C1CCC2C1(CCC3C2CCC4=CC(=O)CCC34C)C
# 2                 CC12CCC3C(C1CCC2O)CCC4=CC(=O)CCC34C
# 3        CC12CCC(=O)C=C1CCC3C2CCC4(C3CCC4(C(=O)CO)O)C
# 4           CC12CCC3C(C1CCC2C(=O)CO)CCC4=CC(=O)CCC34C
# 5    CC12CC(C3C(C1CCC2(C(=O)CO)O)CCC4=CC(=O)C=CC34C)O
# 6   CC1CC2C3CCC4=CC(=O)C=CC4(C3(C(CC2(C1(C(=O)CO)O...
# 7   CC1CC2C3CCC(C3(CC(C2(C4(C1=CC(=O)C=C4)C)F)O)C)...
# 8   CC1(OC2CC3C4CCC5=CC(=O)C=CC5(C4(C(CC3(C2(O1)C(...
# 9   CC(=O)OCC(=O)C1(CCC2C1(CC(C3C2CCC4=CC(=O)C=CC3...
# 10  CC1CC2C3CCC4=CC(=O)C=CC4(C3(C(CC2(C1(C(=O)COC(...
# 11                 CC(C)(C)NCC(COC1=CC=CC=C1C2CCCC2)O
# 12                CCC1=CC=CC2=C1OC(=C2)C(CNC(C)(C)C)O
# 13        CC1=CC(=CC=C1)OCC(CNCCC2=CC(=C(C=C2)OC)OC)O
# 14                   CC(C)NCC(COC1=CC=CC2=CC=CC=C21)O
# 15                CC(C)(C)NCC(COC1=CC=CC2=C1CCCC2=O)O
# ...

# %%
df3 = pd.concat([df1, df2], ignore_index=True)
df3 = df3.drop_duplicates(subset='SMILES', keep='first')
df3.to_csv('merged_reviews2.csv', index=False)
